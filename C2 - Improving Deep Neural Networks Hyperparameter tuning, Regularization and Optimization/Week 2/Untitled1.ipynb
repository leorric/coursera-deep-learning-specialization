# %%
n = 3
for i in range(n):
    print(i)
# Out:
# 0
# 1
# 2

# %%
import numpy as np
m = 3
permutation = list(np.random.permutation(m))

# %%
print(permutation)
# Out:
# [0, 2, 1]

# %%
print(np.random.permutation(m))
# Out:
# [0 2 1]
