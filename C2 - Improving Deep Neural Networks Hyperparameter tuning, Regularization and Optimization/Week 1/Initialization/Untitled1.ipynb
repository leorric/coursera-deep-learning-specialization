# %%
import numpy as np
from gc_utils import sigmoid, relu, dictionary_to_vector, vector_to_dictionary, gradients_to_vector
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import numpy as np
# ----> 2 from gc_utils import sigmoid, relu, dictionary_to_vector, vector_to_dictionary, gradients_to_vector
#
# ModuleNotFoundError: No module named 'gc_utils'

# %%
v = np.zeros((5,1))
print(v)
# Out:
# [[0.]
#  [0.]
#  [0.]
#  [0.]
#  [0.]]

# %%
gradients = {"dZ3": 1, "dW3": 2, "db3": 3}
print(dictionary_to_vector(graidents))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 gradients = {"dZ3": 1, "dW3": 2, "db3": 3}
# ----> 2 print(dictionary_to_vector(graidents))
#
# NameError: name 'dictionary_to_vector' is not defined
